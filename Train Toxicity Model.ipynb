# %% [markdown]
# # Train Toxicity Model

# %% [markdown]
# This notebook trains a model to detect toxicity in online comments. It uses a CNN architecture for text classification trained on the [Wikipedia Talk Labels: Toxicity dataset](https://figshare.com/articles/Wikipedia_Talk_Labels_Toxicity/4563973) and pre-trained GloVe embeddings which can be found at:
# http://nlp.stanford.edu/data/glove.6B.zip
# (source page: http://nlp.stanford.edu/projects/glove/).
#
# This model is a modification of [example code](https://github.com/fchollet/keras/blob/master/examples/pretrained_word_embeddings.py) found in the [Keras Github repository](https://github.com/fchollet/keras) and released under an [MIT license](https://github.com/fchollet/keras/blob/master/LICENSE). For further details of this license, find it [online](https://github.com/fchollet/keras/blob/master/LICENSE) or in this repository in the file KERAS_LICENSE.

# %% [markdown]
# ## Usage Instructions
# (TODO: nthain) - Move to README
#
# Prior to running the notebook, you must:
#
# * Download the [Wikipedia Talk Labels: Toxicity dataset](https://figshare.com/articles/Wikipedia_Talk_Labels_Toxicity/4563973)
# * Download pre-trained [GloVe embeddings](http://nlp.stanford.edu/data/glove.6B.zip)
# * (optional) To skip the training step, you will need to download a model and tokenizer file. We are looking into the appropriate means for distributing these (sometimes large) files.

# %%
# !pip install --upgrade tensorflow==1.4
# Out:
# Collecting tensorflow==1.4
#   Downloading tensorflow-1.4.0-cp27-cp27mu-manylinux1_x86_64.whl (40.7MB)
#     100% |████████████████████████████████| 40.8MB 2.8kB/s ta 0:00:011

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import pandas as pd

from model_tool import ToxModel
from gensim.models.keyedvectors import KeyedVectors
from nltk.corpus import stopwords
import re
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-b585d24a89c6> in <module>()
#       6 import pandas as pd
#       7
# ----> 8 from model_tool import ToxModel
#       9 from gensim.models.keyedvectors import KeyedVectors
#      10 from nltk.corpus import stopwords
#
# /home/dcek/kaggle/model_tool.py in <module>()
#       8 import os
#       9 import numpy as np
# ---> 10 from keras.callbacks import EarlyStopping
#      11 from keras.callbacks import ModelCheckpoint
#      12 from keras.layers import Conv1D
#
# /home/dcek/anaconda2/lib/python2.7/site-packages/keras/__init__.py in <module>()
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# /home/dcek/anaconda2/lib/python2.7/site-packages/keras/utils/__init__.py in <module>()
#       1 from __future__ import absolute_import
# ----> 2 from . import np_utils
#       3 from . import generic_utils
#       4 from . import data_utils
#       5 from . import io_utils
#
# ImportError: cannot import name np_utils

# %%
# !pip install keras==2.0.6
# Out:
# Collecting keras==2.0.6
#   Downloading Keras-2.0.6.tar.gz (228kB)
#     100% |████████████████████████████████| 235kB 541kB/s ta 0:00:01
# Collecting theano (from keras==2.0.6)
#   Downloading Theano-1.0.1.tar.gz (2.8MB)
#     100% |████████████████████████████████| 2.8MB 224kB/s ta 0:00:01
# Requirement already satisfied: pyyaml in /home/dcek/anaconda2/lib/python2.7/site-packages (from keras==2.0.6)
# Requirement already satisfied: six in /home/dcek/anaconda2/lib/python2.7/site-packages (from keras==2.0.6)
# Requirement already satisfied: numpy>=1.9.1 in /home/dcek/anaconda2/lib/python2.7/site-packages (from theano->keras==2.0.6)
# Requirement already satisfied: scipy>=0.14 in /home/dcek/anaconda2/lib/python2.7/site-packages (from theano->keras==2.0.6)
# Building wheels for collected packages: keras, theano
#   Running setup.py bdist_wheel for keras ... done
#   Stored in directory: /home/dcek/.cache/pip/wheels/c2/80/ba/2beab8c2131e2dcc391ee8a2f55e648af66348115c245e0839
#   Running setup.py bdist_wheel for theano ... done
#   Stored in directory: /home/dcek/.cache/pip/wheels/46/a2/7d/b4cac381d5151daa9f9e0b3e4e4b65edaea6355ae296c97cf2
# Successfully built keras theano
# Installing collected packages: theano, keras
#   Found existing installation: Keras 2.1.3
#     Uninstalling Keras-2.1.3:
#       Successfully uninstalled Keras-2.1.3
# Successfully installed keras-2.0.6 theano-1.0.1

# %% [markdown]
# ## Load Data

# %%
training_3rd_vis = pd.read_csv('cleaned_final_train.csv')
display(training_3rd_vis["comment_text"].head(n=20))
n_records_features_vis_3rd = len(training_3rd_vis)
print(" Number of features {}".format(n_records_features_vis_3rd))
train = 'cleaned_final_train.csv'
# Out:
# 0     explanation edits made username hardcore metal...
# 1     aww matches background colour seemingly stuck ...
# 2     hey man really trying edit war guy constantly ...
# 3     make real suggestions improvement wondered sec...
# 4                         sir hero chance remember page
# 5              congratulations well use tools well talk
# 6                           cocksucker piss around work
# 7     vandalism matt shirvington article reverted pl...
# 8     sorry word nonsense offensive anyway intending...
# 9                  alignment subject contrary dulithgow
# 10    fair use rationale image wonju jpg thanks uplo...
# 11                     bbq man lets discuss maybe phone
# 12    hey talk exclusive group wp talibans good dest...
# 13    start throwing accusations warnings lets revie...
# 14    oh girl started arguments stuck nose belong be...
# 15    juelz santanas age two zero zero two juelz san...
# 16              bye look come think comming back tosser
# 17      redirect talk voydan pop georgiev chernodrinski
# 18    mitsurugi point made sense argue include hindi...
# 19    mean bother see writing something regarding re...
# Name: comment_text, dtype: object
#  Number of features 638284

# %%
model_list = []

# %% [markdown]
# ## Train Models

# %%
MODEL_NAME = 'augmentori_cleaned_singlebigru_fasttext_1st'
debias_random_model = ToxModel()
debias_random_model.train(2,train, text_column = 'comment_text', toxic = 'toxic', severe_toxic = 'severe_toxic', obscene = 'obscene', threat = 'threat', insult = 'insult', identity_hate = 'identity_hate', model_name = MODEL_NAME, model_list = model_list)
# Out:
# Hyperparameters
# ---------------
# max_num_words: 199814
# dropout_rate: 0.3
# verbose: True
# cnn_pooling_sizes: [5, 5, 40]
# es_min_delta: 0
# learning_rate: 0.0007
# es_patience: 1
# batch_size: 256
# embedding_dim: 300
# epochs: 1
# cnn_filter_sizes: [128, 128, 128]
# cnn_kernel_sizes: [5, 5, 5]
# max_sequence_length: 250
# stop_early: False
# embedding_trainable: False
#
# Fitting tokenizer...
# Tokenizer fitted!
# Preparing data...
# train_text_temp shape (638284, 250) and train_labels_temp shape (638284, 6)
#  ----
# train_text shape (638284, 250) and train_labels shape (638284, 6)
# Data prepared!
# Loading embeddings...
# Embeddings loaded!
# Building model graph...
# Training model...
# Train on 574456 samples, validate on 63828 samples
# Epoch 1/1
#
# Epoch 00001: val_loss improved from inf to 0.04554, saving model to models/augmentori_cleaned_singlebigru_fasttext_1st0_model.h5
#  - 652s - loss: 0.0676 - acc: 0.9767 - val_loss: 0.0455 - val_acc: 0.9821
# Epoch 0 auc 0.983094783184 best_auc -1
# Train on 574456 samples, validate on 63828 samples
# Epoch 1/1
#
# Epoch 00001: val_loss improved from 0.04554 to 0.04342, saving model to models/augmentori_cleaned_singlebigru_fasttext_1st0_model.h5
#  - 662s - loss: 0.0526 - acc: 0.9809 - val_loss: 0.0434 - val_acc: 0.9826
# Epoch 1 auc 0.985754736097 best_auc 0.983094783184
# Train on 574456 samples, validate on 63828 samples
# Epoch 1/1

# %%
from keras.models import load_model
import os
model_list = []
for fold_id in range(0, 10):
    model_path = 'augmentori_gru_lstm' + str(fold_id)
    model = load_model(
        os.path.join('models', '%s_model.h5' % model_path))
    model_list.append(model)

# %%
from keras.models import load_model
import numpy as np
import os
model_list = []
for fold_id in range(0, 10):
    model_path = 'augmentori_gru_lstm' + str(fold_id)
    model = load_model(
        os.path.join('models', '%s_model.h5' % model_path))
    model_path = os.path.join('models', "model{0}_weights.npy".format(fold_id))
    weights = np.load(model_path)
    model.set_weights(weights)
    model_list.append(model)

# %%
from keras.preprocessing.sequence import pad_sequences
import cPickle
import os
def prep_text(texts):
    """Turns text into into padded sequences.

    The tokenizer must be initialized before calling this method.

    Args:
      texts: Sequence of text strings.

    Returns:
      A tokenized and padded text sequence as a model input.
    """
    model_name = 'augmentori_gru_lstm'
    tokenizer = cPickle.load(
        open(
            os.path.join('models', '%s_tokenizer.pkl' % model_name),
            'rb'))
    text_sequences = tokenizer.texts_to_sequences(texts)
    return pad_sequences(
        text_sequences, maxlen=250)

# %%
total_meta = []
meta_train = pd.read_csv('final_train.csv')
X_test = meta_train['comment_text']
X_test = prep_text(X_test)
X= X_test
fold_size = len(X) // 10
for fold_id in range(0, 10):
    fold_start = fold_size * fold_id
    fold_end = fold_start + fold_size
            
    if fold_id == 10 - 1:
        fold_end = len(X)

    train_x = np.concatenate([X[:fold_start], X[fold_end:]])

    val_x = X[fold_start:fold_end]
          
    meta = model_list[fold_id].predict(val_x, batch_size=128)
    if (fold_id == 0):
        total_meta = meta
    else:
        total_meta = np.concatenate((total_meta, meta), axis=0)

# %%
label_cols = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
subm = pd.read_csv('sample_submission.csv')
submid = pd.DataFrame({'id': subm["id"]})
total_meta_data = pd.concat([submid, pd.DataFrame(total_meta, columns = label_cols)], axis=1)

# %%
display(total_meta_data.head(n=20))
# Out:
#                   id         toxic  severe_toxic       obscene        threat  \
# 0   00001cee341fdb12  5.298672e-07  1.361637e-10  7.528020e-09  3.818864e-10
# 1   0000247867823ef7  2.175462e-06  2.507667e-09  3.737669e-08  7.730432e-10
# 2   00013b17ad220c46  1.382709e-02  1.843092e-07  4.588822e-06  1.099868e-08
# 3   00017563c3f7919a  4.313957e-07  9.578123e-11  6.308026e-09  3.524564e-10
# 4   00017695ad8997eb  2.839943e-06  5.312022e-09  1.006481e-07  1.515298e-09
# 5   0001ea8717f6de06  2.226181e-06  1.201818e-08  6.024056e-08  2.033103e-09
# 6   00024115d4cbde0f  9.997441e-01  9.550502e-04  9.863858e-01  2.469440e-08
# 7   000247e83dcc1211  7.835670e-05  3.863176e-08  1.403170e-07  7.525878e-10
# 8   00025358d4737918  6.994727e-07  4.960894e-10  1.851791e-08  6.080487e-10
# 9   00026d1092fe71cc  1.341810e-06  1.451595e-09  2.378028e-08  4.642549e-10
# 10  0002eadc3b301559  1.986370e-06  9.781389e-11  1.483516e-07  1.452800e-09
# 11  0002f87b16116a7f  9.599260e-06  1.724384e-08  1.678981e-07  2.372269e-09
# 12  0003806b11932181  5.253562e-06  1.791848e-09  2.810255e-08  2.835796e-10
# 13  0003e1cccfd5a40a  6.555797e-05  1.222377e-09  1.898613e-07  2.528772e-09
# 14  00059ace3e3e9a53  1.116358e-06  2.017020e-09  1.635940e-08  5.346498e-10
# 15  000634272d0d44eb  4.985952e-07  1.461743e-10  8.767838e-09  4.608355e-10
# 16  000663aff0fffc80  9.267725e-01  1.172730e-06  6.477467e-04  7.028744e-07
# 17  000689dd34e20979  2.733972e-06  6.897238e-09  3.611359e-08  1.012735e-09
# 18  000834769115370c  1.094949e-06  1.486072e-09  2.094767e-08  7.656855e-10
# 19  000844b52dee5f3f  1.726998e-06  7.215361e-10  1.978880e-08  3.698216e-10
#
#           insult  identity_hate
# 0   3.872117e-08   7.897755e-10
# 1   1.419462e-07   1.429161e-09
# 2   9.896796e-06   1.191894e-07
# 3   3.479985e-08   8.696782e-10
# 4   3.593553e-07   2.260464e-09
# 5   2.641394e-07   3.800403e-09
# 6   9.533083e-01   2.931226e-05
# 7   6.863291e-07   3.154716e-09
# 8   4.313723e-08   7.851165e-10
# 9   8.334749e-08   4.743154e-10
# 10  9.736061e-08   1.490874e-08
# 11  4.836497e-07   2.098017e-09
# 12  1.509382e-07   5.707657e-10
# 13  1.271750e-06   1.798481e-08
# 14  6.028953e-08   9.067921e-10
# 15  5.436491e-08   1.309162e-09
# 16  3.404405e-04   8.409886e-06
# 17  1.205138e-07   1.165219e-09
# 18  7.583320e-08   9.852114e-10
# 19  1.246003e-07   8.946820e-10

# %%
total_meta_data.to_csv('augmentori_meta_grulstmCV_nopretrain.csv', index=False)

# %%
test_predicts = pd.read_csv('gru_cv_output.csv')
display(test_predicts.head(n=20))
test_predicts.shape
# Out:
#                   id     toxic  severe_toxic   obscene        threat  \
# 0   00001cee341fdb12  0.999538  6.181733e-01  0.997640  5.096922e-02
# 1   0000247867823ef7  0.000013  1.247423e-07  0.000003  4.708379e-08
# 2   00013b17ad220c46  0.000055  1.836647e-06  0.000020  6.441840e-07
# 3   00017563c3f7919a  0.000013  2.737614e-07  0.000003  1.778666e-07
# 4   00017695ad8997eb  0.000919  9.784006e-06  0.000113  2.973163e-06
# 5   0001ea8717f6de06  0.000131  1.483309e-06  0.000048  9.474676e-07
# 6   00024115d4cbde0f  0.000043  6.720049e-07  0.000012  7.150590e-07
# 7   000247e83dcc1211  0.295549  2.245386e-04  0.005013  3.404184e-06
# 8   00025358d4737918  0.029627  5.836995e-06  0.000559  3.917941e-07
# 9   00026d1092fe71cc  0.000014  1.825587e-07  0.000002  4.109103e-07
# 10  0002eadc3b301559  0.524255  5.303777e-04  0.273319  2.110697e-05
# 11  0002f87b16116a7f  0.000080  4.553926e-07  0.000031  4.885462e-08
# 12  0003806b11932181  0.000015  7.794360e-08  0.000005  4.036658e-08
# 13  0003e1cccfd5a40a  0.000027  7.491968e-08  0.000004  2.737765e-08
# 14  00059ace3e3e9a53  0.000009  8.513661e-08  0.000002  3.299682e-08
# 15  000634272d0d44eb  0.000244  9.864972e-07  0.000035  1.876895e-07
# 16  000663aff0fffc80  0.000202  2.570370e-06  0.000085  4.309317e-07
# 17  000689dd34e20979  0.000038  2.113363e-07  0.000012  3.975727e-08
# 18  000834769115370c  0.000034  1.898640e-07  0.000011  6.959656e-08
# 19  000844b52dee5f3f  0.001022  1.203353e-05  0.000202  9.268087e-06
#
#           insult  identity_hate
# 0   9.898657e-01   3.255197e-01
# 1   2.553956e-06   1.125692e-06
# 2   1.196271e-05   7.204705e-06
# 3   1.700491e-06   5.387048e-07
# 4   2.222102e-05   6.399844e-06
# 5   1.413156e-05   4.073511e-06
# 6   9.158607e-06   1.265853e-06
# 7   6.566032e-03   1.335455e-04
# 8   1.921604e-03   1.296143e-05
# 9   1.300620e-06   3.998649e-07
# 10  5.117643e-03   2.119174e-05
# 11  7.590138e-06   1.153923e-05
# 12  9.041725e-07   3.523835e-07
# 13  2.101176e-06   5.336782e-07
# 14  7.087185e-07   3.470930e-07
# 15  1.923671e-05   2.114261e-06
# 16  1.627778e-05   1.190652e-05
# 17  2.643774e-06   8.087368e-07
# 18  2.387771e-06   4.670644e-07
# 19  1.202526e-04   9.806483e-06
# (153164, 7)

# %% [markdown]
# ### Random model

# %%
MODEL_NAME = 'multi-labelNLP_charrnn'
debias_random_model = ToxModel()
debias_random_model.train(1,train, text_column = 'comment_text', toxic = 'toxic', severe_toxic = 'severe_toxic', obscene = 'obscene', threat = 'threat', insult = 'insult', identity_hate = 'identity_hate', model_name = MODEL_NAME)
# Out:
# Hyperparameters
# ---------------
# max_num_words: 50000
# dropout_rate: 0.3
# verbose: True
# cnn_pooling_sizes: [5, 5, 40]
# es_min_delta: 0
# learning_rate: 7e-05
# es_patience: 1
# batch_size: 128
# embedding_dim: 300
# epochs: 50
# cnn_filter_sizes: [128, 128, 128]
# cnn_kernel_sizes: [5, 5, 5]
# max_sequence_length: 250
# stop_early: True
# embedding_trainable: False
#
# Fitting tokenizer...
# Tokenizer fitted!
# Preparing data...
# train_text_temp shape (159571, 250) and train_labels_temp shape (159571, 4)
#  ----
# valid_text shape (15958, 250) and valid_labels shape (15958, 4)
# train_text shape (143613, 250) and train_labels shape (143613, 4)
# Data prepared!
# Loading embeddings...
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# nicknamer not in vocabulary
#  not in vocabulary
#  not in vocabulary
# songfulness not in vocabulary
# Elonore not in vocabulary
# homager not in vocabulary
# forebodingness not in vocabulary
#  not in vocabulary
# Fredek not in vocabulary
#  not in vocabulary
# Evaleen not in vocabulary
#  not in vocabulary
#  not in vocabulary
# troths not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Agnesse not in vocabulary
#  not in vocabulary
#  not in vocabulary
# inchoates not in vocabulary
# [] not in vocabulary List is empty
# Sherlocke not in vocabulary
#  not in vocabulary
# attributer not in vocabulary
#  not in vocabulary
# unharnesses not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Saraann not in vocabulary
# philanders not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# matricides not in vocabulary
# crossbarred not in vocabulary
# Natka not in vocabulary
# barning not in vocabulary
# victoriousness not in vocabulary
# Ingaborg not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# objectionableness not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# wimpled not in vocabulary
# filibusterer not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# kriegspiel not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# wickerworks not in vocabulary
#  not in vocabulary
# codeines not in vocabulary
# reedits not in vocabulary
#  not in vocabulary
#  not in vocabulary
# classicisms not in vocabulary
#  not in vocabulary
# venireman not in vocabulary
#  not in vocabulary
# curfs not in vocabulary
# troublesomeness not in vocabulary
# impracticableness not in vocabulary
# selenography not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# wickerworks not in vocabulary
# journalisms not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# bestubble not in vocabulary
# windwards not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# carillonning not in vocabulary
# Rivalee not in vocabulary
# aromaticness not in vocabulary
# gracefuller not in vocabulary
#  not in vocabulary
#  not in vocabulary
# zigzagger not in vocabulary
# underregistration not in vocabulary
# mananas not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# junketeer not in vocabulary
#  not in vocabulary
#  not in vocabulary
# anonymousness not in vocabulary
# excusableness not in vocabulary
#  not in vocabulary
# cassavas not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# paraplegias not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# belligerences not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# hosteler not in vocabulary
# Noelyn not in vocabulary
# Anatola not in vocabulary
#  not in vocabulary
# Gavrielle not in vocabulary
# baloneys not in vocabulary
# [] not in vocabulary List is empty
# antiabortionist not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Morganica not in vocabulary
#  not in vocabulary
#  not in vocabulary
# mistruster not in vocabulary
# Chanukahs not in vocabulary
#  not in vocabulary
# scratchily not in vocabulary
# nicknamer not in vocabulary
# ultimateness not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# insolubleness not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Ramadans not in vocabulary
#  not in vocabulary
# Vilyui not in vocabulary
# Morgun not in vocabulary
#  not in vocabulary
# histochemic not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Corrianne not in vocabulary
# pitchstone not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# ranees not in vocabulary
#  not in vocabulary
#  not in vocabulary
# camerawomen not in vocabulary
#  not in vocabulary
#  not in vocabulary
# hairsplitter not in vocabulary
# conservatisms not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# hypothalami not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# mutably not in vocabulary
# winemaster not in vocabulary
# detestableness not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Ellette not in vocabulary
#  not in vocabulary
# interbreeds not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# dolefuller not in vocabulary
# differer not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# inexhaustibleness not in vocabulary
# kriegspiel not in vocabulary
# cannibalisms not in vocabulary
# Confucianisms not in vocabulary
# rarebits not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# halalled not in vocabulary
#  not in vocabulary
# Visakhapatnams not in vocabulary
# [] not in vocabulary List is empty
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
# alluvials not in vocabulary
#  not in vocabulary
#  not in vocabulary
# wolfishness not in vocabulary
#  not in vocabulary
#  not in vocabulary
# barbwires not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# unresistant not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Filberto not in vocabulary
#  not in vocabulary
# callows not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# matricidal not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Norean not in vocabulary
#  not in vocabulary
# embattle not in vocabulary
# gracefullest not in vocabulary
#  not in vocabulary
#  not in vocabulary
# pamperer not in vocabulary
#  not in vocabulary
# Nikaniki not in vocabulary
#  not in vocabulary
# Tawsha not in vocabulary
# anonymities not in vocabulary
# [] not in vocabulary List is empty
# Shandie not in vocabulary
#  not in vocabulary
# catercorner not in vocabulary
# presentableness not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# Petkiewicz not in vocabulary
# loyaler not in vocabulary
#  not in vocabulary
# incorrigibleness not in vocabulary
#  not in vocabulary
# ceaselessness not in vocabulary
#  not in vocabulary
# Hejiras not in vocabulary
# pericardia not in vocabulary
#  not in vocabulary
#  not in vocabulary
# nonindependent not in vocabulary
# Michaelina not in vocabulary
#  not in vocabulary
#  not in vocabulary
# campanological not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
# dissipatedness not in vocabulary
#  not in vocabulary
#  not in vocabulary
# musicianships not in vocabulary
# mahjongs not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# campanologist not in vocabulary
#  not in vocabulary
# reprinter not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Christianizes not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# dyslexically not in vocabulary
# preluder not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# moderatenesses not in vocabulary
# Ingamar not in vocabulary
# jiujitsus not in vocabulary
# subcomputation not in vocabulary
#  not in vocabulary
# archfiends not in vocabulary
#  not in vocabulary
# foxtrotting not in vocabulary
# electroencephalographs not in vocabulary
# adverseness not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Maurise not in vocabulary
#  not in vocabulary
# swampiest not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# undergrounder not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Husains not in vocabulary
# jurisprudences not in vocabulary
#  not in vocabulary
# prospectiveness not in vocabulary
# whitings not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# ergophobia not in vocabulary
# Joseito not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# lamebrains not in vocabulary
#  not in vocabulary
# Fanchette not in vocabulary
# metalanguages not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# miscopying not in vocabulary
#  not in vocabulary
# featherbrain not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Winehead not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# austereness not in vocabulary
#  not in vocabulary
#  not in vocabulary
# imperfectability not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# empaneling not in vocabulary
#  not in vocabulary
#  not in vocabulary
# gabbiness not in vocabulary
# irenics not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Galahads not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# rookiest not in vocabulary
#  not in vocabulary
# barefacedness not in vocabulary
# Menkalinan not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Sosanna not in vocabulary
# radiopasteurization not in vocabulary
# Oderbergs not in vocabulary
# Doralia not in vocabulary
# filterer not in vocabulary
# [] not in vocabulary List is empty
# Italianates not in vocabulary
# petrologist not in vocabulary
# Guntar not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# hajjes not in vocabulary
# hajjes not in vocabulary
# hajjes not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
# Petkiewicz not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# obiing not in vocabulary
# Davidde not in vocabulary
#  not in vocabulary
# deerstalkers not in vocabulary
# trisector not in vocabulary
# Donaugh not in vocabulary
# Zubeneschamali not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# columnize not in vocabulary
# falterer not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# blacklister not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# pachysandras not in vocabulary
# cyclopedias not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# serviceableness not in vocabulary
# [] not in vocabulary List is empty
# [] not in vocabulary List is empty
#  not in vocabulary
# deferrer not in vocabulary
#  not in vocabulary
# disguiser not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# unravellings not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Agnella not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# carrions not in vocabulary
# dilapidates not in vocabulary
#  not in vocabulary
#  not in vocabulary
# homophobias not in vocabulary
# misstater not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Duky not in vocabulary
# electroencephalographs not in vocabulary
#  not in vocabulary
#  not in vocabulary
# gunnysacks not in vocabulary
# seditiousness not in vocabulary
# remorses not in vocabulary
# anticked not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# deerstalking not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
# grumpinesses not in vocabulary
#  not in vocabulary
# Kettie not in vocabulary
# Johnath not in vocabulary
#  not in vocabulary
#  not in vocabulary
# isomerisms not in vocabulary
# cumulonimbi not in vocabulary
# bedevilments not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# searer not in vocabulary
# OHiggins not in vocabulary
#  not in vocabulary
#  not in vocabulary
# buckrams not in vocabulary
# Nevadian not in vocabulary
#  not in vocabulary
# hammier not in vocabulary
# deleteriousness not in vocabulary
# foremasts not in vocabulary
#  not in vocabulary
# conservatisms not in vocabulary
# detailedness not in vocabulary
# cliometrician not in vocabulary
#  not in vocabulary
# underenumeration not in vocabulary
# mananas not in vocabulary
#  not in vocabulary
# savoringly not in vocabulary
#  not in vocabulary
# muddily not in vocabulary
#  not in vocabulary
#  not in vocabulary
# autorepeats not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Gabriellia not in vocabulary
#  not in vocabulary
#  not in vocabulary
# traffickings not in vocabulary
#  not in vocabulary
#  not in vocabulary
# communisms not in vocabulary
#  not in vocabulary
# sackcloths not in vocabulary
# Modestia not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
# cherisher not in vocabulary
#  not in vocabulary
# buttoner not in vocabulary
# homeostases not in vocabulary
#  not in vocabulary
#  not in vocabulary
# plutoniums not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# fustians not in vocabulary
#  not in vocabulary
#  not in vocabulary
# dumbnesses not in vocabulary
# indistinguishableness not in vocabulary
# quackish not in vocabulary
#  not in vocabulary
#  not in vocabulary
# benefiter not in vocabulary
#  not in vocabulary
# towardliness not in vocabulary
#  not in vocabulary
# demonstrativenesses not in vocabulary
# gonion not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# tutelaries not in vocabulary
#  not in vocabulary
# Delcine not in vocabulary
#  not in vocabulary
#  not in vocabulary
# indefatigableness not in vocabulary
# Ratfor not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# homeomorph not in vocabulary
#  not in vocabulary
#  not in vocabulary
# brainteasing not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Heinrik not in vocabulary
#  not in vocabulary
# patenter not in vocabulary
# handbarrow not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# godding not in vocabulary
#  not in vocabulary
# supplely not in vocabulary
#  not in vocabulary
# Nikaniki not in vocabulary
# Arianist not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# knowledgeableness not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# zigzagger not in vocabulary
# Exchequers not in vocabulary
#  not in vocabulary
#  not in vocabulary
# magnetohydrodynamical not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Jurua not in vocabulary
#  not in vocabulary
# chanciness not in vocabulary
#  not in vocabulary
# maydays not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# trinketed not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# outargued not in vocabulary
# Reichstags not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# bluffness not in vocabulary
# whippletrees not in vocabulary
# baconer not in vocabulary
#  not in vocabulary
#  not in vocabulary
# babels not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# angelicas not in vocabulary
# cartages not in vocabulary
# Annadiana not in vocabulary
# familiarizer not in vocabulary
#  not in vocabulary
# Walliw not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# desirabilia not in vocabulary
#  not in vocabulary
#  not in vocabulary
# timothies not in vocabulary
#  not in vocabulary
# differer not in vocabulary
# Ingeberg not in vocabulary
# pitchstone not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Loutitia not in vocabulary
# sixshooter not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Minnaminnie not in vocabulary
# populisms not in vocabulary
# Sidonnie not in vocabulary
# vintager not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# Jillana not in vocabulary
# Gayel not in vocabulary
#  not in vocabulary
# fortieths not in vocabulary
# motioner not in vocabulary
# autosuggestibility not in vocabulary
# Indianian not in vocabulary
# perpend not in vocabulary
#  not in vocabulary
#  not in vocabulary
# hypothalamically not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# becked not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# [] not in vocabulary List is empty
#  not in vocabulary
# sadisms not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Tsitsihar not in vocabulary
# agapes not in vocabulary
# Karlotte not in vocabulary
# tauts not in vocabulary
# [] not in vocabulary List is empty
# sectionalisms not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# plainclothesman not in vocabulary
#  not in vocabulary
# handbarrow not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# verticess not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Jurua not in vocabulary
#  not in vocabulary
# Hurleigh not in vocabulary
# Amandie not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# soapboxed not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Caritta not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# overbooks not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Isahella not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# [] not in vocabulary List is empty
#  not in vocabulary
# anaphorically not in vocabulary
#  not in vocabulary
# Netzahualcoyotl not in vocabulary
#  not in vocabulary
# shanghais not in vocabulary
#  not in vocabulary
# remorses not in vocabulary
# retrovision not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# palatines not in vocabulary
# Puritanisms not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# misguidedness not in vocabulary
# Wilone not in vocabulary
#  not in vocabulary
#  not in vocabulary
# intraindustry not in vocabulary
#  not in vocabulary
# muleskinners not in vocabulary
#  not in vocabulary
# interindustry not in vocabulary
# bariums not in vocabulary
# moper not in vocabulary
#  not in vocabulary
# denunciates not in vocabulary
#  not in vocabulary
#  not in vocabulary
# ceders not in vocabulary
#  not in vocabulary
# fusser not in vocabulary
#  not in vocabulary
# Dalenna not in vocabulary
#  not in vocabulary
#  not in vocabulary
# cunnings not in vocabulary
# revet not in vocabulary
#  not in vocabulary
# dinnertimes not in vocabulary
# imponderableness not in vocabulary
#  not in vocabulary
#  not in vocabulary
# earwigged not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# beribbon not in vocabulary
# parturitions not in vocabulary
#  not in vocabulary
# insentience not in vocabulary
#  not in vocabulary
#  not in vocabulary
# paludal not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
# Ngaliema not in vocabulary
# paraphraser not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# sickishness not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# Pyhrric not in vocabulary
#  not in vocabulary
# misdoes not in vocabulary
#  not in vocabulary
# hdqrs not in vocabulary
# mouthorgan not in vocabulary
#  not in vocabulary
# Hollyanne not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Nikaniki not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Korella not in vocabulary
#  not in vocabulary
# contemplativeness not in vocabulary
# desirabilia not in vocabulary
#  not in vocabulary
# shantis not in vocabulary
# opennesses not in vocabulary
# Nazisms not in vocabulary
#  not in vocabulary
# electromyographically not in vocabulary
# abater not in vocabulary
# biophysic not in vocabulary
# Koressa not in vocabulary
# idolizer not in vocabulary
# bulldogger not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# paperiness not in vocabulary
#  not in vocabulary
# Othilie not in vocabulary
# honorarily not in vocabulary
# Annabal not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# scolder not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Datamedia not in vocabulary
#  not in vocabulary
# equiproportionality not in vocabulary
# remorsefulness not in vocabulary
#  not in vocabulary
# determinativeness not in vocabulary
#  not in vocabulary
# brackishness not in vocabulary
#  not in vocabulary
# Betteann not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Styrofoams not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Shurwood not in vocabulary
# shakably not in vocabulary
# bibliographics not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Eada not in vocabulary
# motioner not in vocabulary
# selenography not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# busgirl not in vocabulary
# [] not in vocabulary List is empty
# venously not in vocabulary
# arrayer not in vocabulary
# tortoni not in vocabulary
#  not in vocabulary
# carbuncular not in vocabulary
# ipecacs not in vocabulary
# rakishness not in vocabulary
# Annadiana not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# ohos not in vocabulary
#  not in vocabulary
# Reginauld not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Kettie not in vocabulary
# agreers not in vocabulary
#  not in vocabulary
# Francyne not in vocabulary
#  not in vocabulary
# cholers not in vocabulary
#  not in vocabulary
# cyclopedias not in vocabulary
# attentionality not in vocabulary
#  not in vocabulary
#  not in vocabulary
# peasanthood not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# outfaced not in vocabulary
# dumdums not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Sanskritize not in vocabulary
#  not in vocabulary
# geocentricism not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# uraniums not in vocabulary
#  not in vocabulary
# disreputableness not in vocabulary
# monarchistic not in vocabulary
# hdqrs not in vocabulary
# Fahrenheits not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# disinformations not in vocabulary
# pericardia not in vocabulary
#  not in vocabulary
# Nefen not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# Aguistin not in vocabulary
#  not in vocabulary
# Gayel not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# maladapt not in vocabulary
# diapasons not in vocabulary
#  not in vocabulary
# readabilities not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# seasonableness not in vocabulary
# Liuka not in vocabulary
#  not in vocabulary
# channelizes not in vocabulary
# Bentlee not in vocabulary
# Dalenna not in vocabulary
# haggards not in vocabulary
#  not in vocabulary
#  not in vocabulary
# gallanting not in vocabulary
#  not in vocabulary
# palladiums not in vocabulary
#  not in vocabulary
# intracohort not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Ursola not in vocabulary
# Devondra not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# adversed not in vocabulary
# ecumenicisms not in vocabulary
# autosuggestibility not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Cristionna not in vocabulary
#  not in vocabulary
# silentness not in vocabulary
# servileness not in vocabulary
#  not in vocabulary
#  not in vocabulary
# pigswill not in vocabulary
# Sheeree not in vocabulary
# Saudra not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# poppycocks not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Dianemarie not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Artair not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
# Sherwynd not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# cupidinously not in vocabulary
# cabinetries not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# dybbuks not in vocabulary
# indubitableness not in vocabulary
#  not in vocabulary
#  not in vocabulary
# causate not in vocabulary
# dilapidates not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# barnsful not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Sukkots not in vocabulary
#  not in vocabulary
# ripener not in vocabulary
# prestidigitatorial not in vocabulary
# pothers not in vocabulary
#  not in vocabulary
#  not in vocabulary
# pleonasms not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# iratenesses not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# clearheadedness not in vocabulary
# upstater not in vocabulary
# peregrinating not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# worldliest not in vocabulary
# Bartolemo not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# trodes not in vocabulary
#  not in vocabulary
#  not in vocabulary
# preciser not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# mouthorgan not in vocabulary
# [] not in vocabulary List is empty
# Dulcine not in vocabulary
#  not in vocabulary
#  not in vocabulary
# gasohols not in vocabulary
# tauts not in vocabulary
# Reichstags not in vocabulary
# widowhoods not in vocabulary
#  not in vocabulary
# Donaugh not in vocabulary
# maharanis not in vocabulary
# contemplativeness not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# shrewishness not in vocabulary
# libeler not in vocabulary
#  not in vocabulary
#  not in vocabulary
# ransomer not in vocabulary
#  not in vocabulary
# sprier not in vocabulary
# hypersensitiveness not in vocabulary
#  not in vocabulary
# isomerisms not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# banqueter not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# shingler not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# informativenesses not in vocabulary
# Petkiewicz not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# impracticableness not in vocabulary
#  not in vocabulary
# beriberis not in vocabulary
# alundum not in vocabulary
# antihistorical not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# thermostatted not in vocabulary
# flannelet not in vocabulary
# lambadas not in vocabulary
# scragging not in vocabulary
# corroborator not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# leeriness not in vocabulary
# meretriciousness not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Farand not in vocabulary
# radiogalaxy not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# hayrick not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# Jorry not in vocabulary
#  not in vocabulary
# contumelies not in vocabulary
# Tokyoite not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# trousseaux not in vocabulary
# Marsiella not in vocabulary
#  not in vocabulary
# extemporaneousness not in vocabulary
# lovableness not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# airest not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# thiamines not in vocabulary
# elastodynamics not in vocabulary
# [] not in vocabulary List is empty
# ballcocks not in vocabulary
#  not in vocabulary
# killdeers not in vocabulary
# hoofmark not in vocabulary
#  not in vocabulary
# nonfreezing not in vocabulary
# outvotes not in vocabulary
# toadyism not in vocabulary
# shantis not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Latrena not in vocabulary
#  not in vocabulary
# finites not in vocabulary
#  not in vocabulary
#  not in vocabulary
# petrologist not in vocabulary
# unassigns not in vocabulary
#  not in vocabulary
# purisms not in vocabulary
# supermachine not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# cretinisms not in vocabulary
# breastbones not in vocabulary
# brackens not in vocabulary
# electroencephalographs not in vocabulary
#  not in vocabulary
# disreputes not in vocabulary
#  not in vocabulary
# Gerhardine not in vocabulary
#  not in vocabulary
#  not in vocabulary
# monkeyshine not in vocabulary
# hydraulicking not in vocabulary
# friedcake not in vocabulary
# dratting not in vocabulary
#  not in vocabulary
# Melamie not in vocabulary
#  not in vocabulary
#  not in vocabulary
# womenfolks not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# doters not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# legmen not in vocabulary
# Americanizations not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# clamorer not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Rayshell not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# promenader not in vocabulary
# balefuller not in vocabulary
# nonbelligerent not in vocabulary
#  not in vocabulary
# barning not in vocabulary
# Aubine not in vocabulary
# crowbait not in vocabulary
#  not in vocabulary
# Heinrik not in vocabulary
#  not in vocabulary
# nerviness not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# augustness not in vocabulary
# burnables not in vocabulary
#  not in vocabulary
# halfheartedness not in vocabulary
#  not in vocabulary
# Allianora not in vocabulary
#  not in vocabulary
# empaneling not in vocabulary
#  not in vocabulary
#  not in vocabulary
# garred not in vocabulary
#  not in vocabulary
#  not in vocabulary
# mananas not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# Indianian not in vocabulary
#  not in vocabulary
# Meredithe not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# fingerer not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Ezmeralda not in vocabulary
#  not in vocabulary
# Tsitsihar not in vocabulary
# Lucais not in vocabulary
#  not in vocabulary
# bloodlessnesses not in vocabulary
#  not in vocabulary
# editorializer not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# baleens not in vocabulary
# venisons not in vocabulary
# Unitarianisms not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# quintillionth not in vocabulary
#  not in vocabulary
# godded not in vocabulary
# octennial not in vocabulary
# ohos not in vocabulary
# imperfectability not in vocabulary
#  not in vocabulary
#  not in vocabulary
# rennins not in vocabulary
# nepotist not in vocabulary
# Nanice not in vocabulary
# dipodic not in vocabulary
#  not in vocabulary
# cancans not in vocabulary
#  not in vocabulary
#  not in vocabulary
# garlicking not in vocabulary
#  not in vocabulary
#  not in vocabulary
# telephotography not in vocabulary
# overoptimism not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# autosuggestibility not in vocabulary
# [] not in vocabulary List is empty
# roisterer not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Nikaniki not in vocabulary
# Nikaniki not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# lanthanums not in vocabulary
#  not in vocabulary
#  not in vocabulary
# billposters not in vocabulary
#  not in vocabulary
#  not in vocabulary
# jetsams not in vocabulary
# impressionableness not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Obadias not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Anglophobes not in vocabulary
# megaword not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Ingamar not in vocabulary
#  not in vocabulary
#  not in vocabulary
# cockeye not in vocabulary
#  not in vocabulary
#  not in vocabulary
# chargeableness not in vocabulary
#  not in vocabulary
#  not in vocabulary
# pimplike not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Thornie not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Kakalina not in vocabulary
#  not in vocabulary
# sharkskins not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Yolane not in vocabulary
# Janenna not in vocabulary
#  not in vocabulary
# vagarious not in vocabulary
#  not in vocabulary
# incarnadined not in vocabulary
#  not in vocabulary
# Bahamanians not in vocabulary
#  not in vocabulary
# Willabella not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# Mariquilla not in vocabulary
#  not in vocabulary
# papergirls not in vocabulary
#  not in vocabulary
# Christean not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Saidee not in vocabulary
#  not in vocabulary
# gigacycles not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# historicalness not in vocabulary
#  not in vocabulary
# incentively not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# cohabitational not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# Nefen not in vocabulary
#  not in vocabulary
# averrer not in vocabulary
#  not in vocabulary
# Exchequers not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# velarize not in vocabulary
#  not in vocabulary
#  not in vocabulary
# elodeas not in vocabulary
# proximateness not in vocabulary
# marlinespikes not in vocabulary
# Hatchure not in vocabulary
# kelpers not in vocabulary
# semitics not in vocabulary
#  not in vocabulary
# lanthanums not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# acidoses not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Celestyn not in vocabulary
#  not in vocabulary
# stouten not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# nonplussing not in vocabulary
# metathesized not in vocabulary
# indeterminably not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# megaword not in vocabulary
# Wilone not in vocabulary
#  not in vocabulary
#  not in vocabulary
# insubordinates not in vocabulary
# Cherye not in vocabulary
#  not in vocabulary
#  not in vocabulary
# radiopasteurization not in vocabulary
# consequentialness not in vocabulary
# Chiarra not in vocabulary
# busher not in vocabulary
# hesitater not in vocabulary
#  not in vocabulary
#  not in vocabulary
# uprear not in vocabulary
#  not in vocabulary
# decrepitudes not in vocabulary
#  not in vocabulary
# buttonweed not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Isahella not in vocabulary
# ranees not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# coiffing not in vocabulary
#  not in vocabulary
# nicotines not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Flemished not in vocabulary
#  not in vocabulary
# engrosser not in vocabulary
# sinisterness not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Mullikan not in vocabulary
#  not in vocabulary
# Kristoforo not in vocabulary
# rakishness not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Annadiana not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# demimondaines not in vocabulary
# stormbound not in vocabulary
# Katuscha not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Americanizations not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Caroljean not in vocabulary
# Aprilette not in vocabulary
# epiglottises not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# saltinesses not in vocabulary
#  not in vocabulary
# shirtmake not in vocabulary
#  not in vocabulary
#  not in vocabulary
# clandestineness not in vocabulary
#  not in vocabulary
# Ingeberg not in vocabulary
# Agace not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# glottalization not in vocabulary
# ignorantness not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# backarrow not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
# Shanghaiing not in vocabulary
#  not in vocabulary
#  not in vocabulary
# misrepresenter not in vocabulary
# Donaugh not in vocabulary
#  not in vocabulary
#  not in vocabulary
# magnetohydrodynamical not in vocabulary
# overcapitalize not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Marylinda not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# contemplativeness not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
# Susanetta not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# kilocycle not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# maharanis not in vocabulary
# warrener not in vocabulary
#  not in vocabulary
# Jillane not in vocabulary
# revertible not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# reallying not in vocabulary
# whirler not in vocabulary
# urbanologist not in vocabulary
#  not in vocabulary
# Linoel not in vocabulary
#  not in vocabulary
# macrosocioeconomic not in vocabulary
#  not in vocabulary
# delfs not in vocabulary
#  not in vocabulary
# hajjes not in vocabulary
# mouing not in vocabulary
#  not in vocabulary
# dipodic not in vocabulary
# irrationalness not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# shorer not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Walliw not in vocabulary
#  not in vocabulary
#  not in vocabulary
# austereness not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Sheratan not in vocabulary
#  not in vocabulary
# crumminess not in vocabulary
# kielbasi not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Gwenore not in vocabulary
# Padrewski not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Ricoriki not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# balefullest not in vocabulary
#  not in vocabulary
#  not in vocabulary
# analgesias not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# withdrawnness not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# schussboomer not in vocabulary
# alliterates not in vocabulary
# hydrocephali not in vocabulary
#  not in vocabulary
#  not in vocabulary
# lifelikeness not in vocabulary
#  not in vocabulary
# satisfactoriness not in vocabulary
#  not in vocabulary
# Finnbogadottir not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Dniren not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Barbabas not in vocabulary
#  not in vocabulary
# turniped not in vocabulary
# granduncles not in vocabulary
# Kariotta not in vocabulary
#  not in vocabulary
# woodbines not in vocabulary
#  not in vocabulary
# balloter not in vocabulary
# telekineses not in vocabulary
#  not in vocabulary
#  not in vocabulary
# rumorer not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# fishily not in vocabulary
# enunciable not in vocabulary
# electroplates not in vocabulary
# Weisenheimer not in vocabulary
#  not in vocabulary
# Nevsa not in vocabulary
#  not in vocabulary
# spectrographically not in vocabulary
# Shandie not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# hypermedias not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# choroids not in vocabulary
# shirrs not in vocabulary
# galvanometric not in vocabulary
#  not in vocabulary
# ebulliences not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Olenolin not in vocabulary
# toastmistress not in vocabulary
# magnetohydrodynamical not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# anthraces not in vocabulary
# Nevadian not in vocabulary
#  not in vocabulary
# rhymesters not in vocabulary
# fritterer not in vocabulary
# Kwanzaas not in vocabulary
# Markism not in vocabulary
# overfeeds not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Markism not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Rafaellle not in vocabulary
#  not in vocabulary
#  not in vocabulary
# squadded not in vocabulary
# simonizes not in vocabulary
# nonplussing not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# interchangeableness not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
# sanguineness not in vocabulary
#  not in vocabulary
# Mohandis not in vocabulary
#  not in vocabulary
#  not in vocabulary
# waister not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Hallsy not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# ...
#  not in vocabulary
# Krishnah not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# shadowiness not in vocabulary
#  not in vocabulary
# Celestyn not in vocabulary
#  not in vocabulary
#  not in vocabulary
# deleteriousness not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# Melisenda not in vocabulary
# complementariness not in vocabulary
# bravadoes not in vocabulary
# [] not in vocabulary List is empty
# notepapers not in vocabulary
#  not in vocabulary
#  not in vocabulary
# towardliness not in vocabulary
#  not in vocabulary
#  not in vocabulary
# grovelike not in vocabulary
# anastigmatic not in vocabulary
#  not in vocabulary
# indiscriminateness not in vocabulary
# effendis not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# Shanghaiing not in vocabulary
# remediableness not in vocabulary
# wases not in vocabulary
# affricative not in vocabulary
# Kariotta not in vocabulary
# Abagael not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# sniveler not in vocabulary
# indefatigableness not in vocabulary
# lactoses not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# chafferer not in vocabulary
# legginesses not in vocabulary
#  not in vocabulary
# Indianian not in vocabulary
#  not in vocabulary
# tinfoils not in vocabulary
#  not in vocabulary
# Isahella not in vocabulary
#  not in vocabulary
#  not in vocabulary
# inspective not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# Marylinda not in vocabulary
# viragoes not in vocabulary
# outhits not in vocabulary
# unitalicized not in vocabulary
# Wallache not in vocabulary
# brigandages not in vocabulary
# stenos not in vocabulary
# Ammamaria not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# nephritides not in vocabulary
# delectableness not in vocabulary
#  not in vocabulary
#  not in vocabulary
# lifetaking not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# radiophones not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Turkics not in vocabulary
#  not in vocabulary
# Welbie not in vocabulary
# emblazonment not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Sherye not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Shebeli not in vocabulary
#  not in vocabulary
# calciums not in vocabulary
#  not in vocabulary
# interchangeableness not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# filterer not in vocabulary
# Heall not in vocabulary
# Kippar not in vocabulary
#  not in vocabulary
# encephalographic not in vocabulary
# einsteiniums not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Reichstags not in vocabulary
# amened not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# calumets not in vocabulary
#  not in vocabulary
#  not in vocabulary
# interindex not in vocabulary
# presumingly not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Gothart not in vocabulary
# redoubtably not in vocabulary
# Karlotta not in vocabulary
# [] not in vocabulary List is empty
# syncopative not in vocabulary
#  not in vocabulary
#  not in vocabulary
# niggler not in vocabulary
# Putnem not in vocabulary
#  not in vocabulary
# antivenins not in vocabulary
# nepotist not in vocabulary
# Waylin not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# [] not in vocabulary List is empty
#  not in vocabulary
# classicisms not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
#  not in vocabulary
# Number of words replaced: 108016  Failed: 10805
# Embeddings loaded!
# Building model graph...
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 250)           0
# ____________________________________________________________________________________________________
# embedding_1 (Embedding)          (None, 250, 300)      63166500    input_1[0][0]
# ____________________________________________________________________________________________________
# bidirectional_2 (Bidirectional)  (None, 250, 100)      140400      embedding_1[0][0]
# ____________________________________________________________________________________________________
# bidirectional_1 (Bidirectional)  (None, 250, 100)      140400      embedding_1[0][0]
# ____________________________________________________________________________________________________
# attention_2 (Attention)          (None, 100)           350         bidirectional_2[0][0]
# ____________________________________________________________________________________________________
# attention_1 (Attention)          (None, 100)           350         bidirectional_1[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                  (None, 128)           12928       attention_2[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 128)           12928       attention_1[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128)           0           dense_4[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 128)           0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dense_5 (Dense)                  (None, 128)           16512       dropout_3[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 128)           16512       dropout_1[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 128)           0           dense_5[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 128)           0           dense_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 128)           512         dropout_4[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 128)           512         dropout_2[0][0]
# ____________________________________________________________________________________________________
# dense_6 (Dense)                  (None, 6)             774         batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 6)             774         batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 12)            0           dense_6[0][0]
#                                                                    dense_3[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 12)            0           concatenate_1[0][0]
# ____________________________________________________________________________________________________
# dense_7 (Dense)                  (None, 128)           1664        dropout_5[0][0]
# ____________________________________________________________________________________________________
# dense_8 (Dense)                  (None, 4)             516         dense_7[0][0]
# ====================================================================================================
# Total params: 63,511,632
# Trainable params: 344,620
# Non-trainable params: 63,167,012
# ____________________________________________________________________________________________________
# Training model...
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/50
# Epoch 00000: val_loss improved from inf to 0.08809, saving model to models/multi-labelNLP_model.h5
# 1049s - loss: 0.2646 - acc: 0.9442 - val_loss: 0.0881 - val_acc: 0.9708
# Epoch 2/50
# Epoch 00001: val_loss improved from 0.08809 to 0.06706, saving model to models/multi-labelNLP_model.h5
# 1045s - loss: 0.0788 - acc: 0.9715 - val_loss: 0.0671 - val_acc: 0.9708
# Epoch 3/50
# Epoch 00002: val_loss improved from 0.06706 to 0.05972, saving model to models/multi-labelNLP_model.h5
# 1011s - loss: 0.0646 - acc: 0.9774 - val_loss: 0.0597 - val_acc: 0.9833
# Epoch 4/50
# Epoch 00003: val_loss improved from 0.05972 to 0.05452, saving model to models/multi-labelNLP_model.h5
# 1000s - loss: 0.0581 - acc: 0.9799 - val_loss: 0.0545 - val_acc: 0.9837
# Epoch 5/50
# Epoch 00004: val_loss improved from 0.05452 to 0.05107, saving model to models/multi-labelNLP_model.h5
# 991s - loss: 0.0541 - acc: 0.9820 - val_loss: 0.0511 - val_acc: 0.9845
# Epoch 6/50
# Epoch 00005: val_loss improved from 0.05107 to 0.04932, saving model to models/multi-labelNLP_model.h5
# 990s - loss: 0.0512 - acc: 0.9840 - val_loss: 0.0493 - val_acc: 0.9846
# Epoch 7/50
# Epoch 00006: val_loss improved from 0.04932 to 0.04794, saving model to models/multi-labelNLP_model.h5
# 990s - loss: 0.0493 - acc: 0.9841 - val_loss: 0.0479 - val_acc: 0.9847
# Epoch 8/50
# Epoch 00007: val_loss improved from 0.04794 to 0.04689, saving model to models/multi-labelNLP_model.h5
# 987s - loss: 0.0478 - acc: 0.9844 - val_loss: 0.0469 - val_acc: 0.9849
# Epoch 9/50
# Epoch 00008: val_loss did not improve
# 953s - loss: 0.0464 - acc: 0.9847 - val_loss: 0.0474 - val_acc: 0.9849
# Epoch 10/50
# Epoch 00009: val_loss improved from 0.04689 to 0.04633, saving model to models/multi-labelNLP_model.h5
# 957s - loss: 0.0455 - acc: 0.9847 - val_loss: 0.0463 - val_acc: 0.9853
# Epoch 11/50
# Epoch 00010: val_loss improved from 0.04633 to 0.04528, saving model to models/multi-labelNLP_model.h5
# 957s - loss: 0.0448 - acc: 0.9848 - val_loss: 0.0453 - val_acc: 0.9855
# Epoch 12/50
# Epoch 00011: val_loss did not improve
# 955s - loss: 0.0441 - acc: 0.9851 - val_loss: 0.0463 - val_acc: 0.9854
# Epoch 13/50
# Epoch 00012: val_loss improved from 0.04528 to 0.04468, saving model to models/multi-labelNLP_model.h5
# 959s - loss: 0.0429 - acc: 0.9853 - val_loss: 0.0447 - val_acc: 0.9854
# Epoch 14/50
# Epoch 00013: val_loss did not improve
# 957s - loss: 0.0426 - acc: 0.9851 - val_loss: 0.0449 - val_acc: 0.9854
# Epoch 15/50
# Epoch 00014: val_loss did not improve
# 956s - loss: 0.0420 - acc: 0.9852 - val_loss: 0.0457 - val_acc: 0.9854
# Epoch 00014: early stopping
# Model trained!
# Best model saved to models/multi-labelNLP_model.h5
# Loading best model from checkpoint...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-d60a1c8818fd> in <module>()
#       1 MODEL_NAME = 'multi-labelNLP'
#       2 debias_random_model = ToxModel()
# ----> 3 debias_random_model.train(1,train, text_column = 'comment_text', toxic = 'toxic', severe_toxic = 'severe_toxic', obscene = 'obscene', threat = 'threat', insult = 'insult', identity_hate = 'identity_hate', model_name = MODEL_NAME)
#
# /media/dcek/ExtraDrive21/git/Kaggle/model_tool.py in train(self, cl, training_data_path, text_column, toxic, severe_toxic, obscene, threat, insult, identity_hate, model_name, pretrain)
#     476         epochs=self.hparams['epochs'],
#     477         validation_data=(valid_text, valid_labels),
# --> 478         callbacks=callbacks,
#     479         verbose=2)
#     480     print('Model trained!')
#
# /home/dcek/anaconda2/envs/py27/lib/python2.7/site-packages/keras/models.pyc in load_model(filepath, custom_objects, compile)
#     237             raise ValueError('No model found in config file.')
#     238         model_config = json.loads(model_config.decode('utf-8'))
# --> 239         model = model_from_config(model_config, custom_objects=custom_objects)
#     240
#     241         # set weights
#
# /home/dcek/anaconda2/envs/py27/lib/python2.7/site-packages/keras/models.pyc in model_from_config(config, custom_objects)
#     311                         'Maybe you meant to use '
#     312                         '`Sequential.from_config(config)`?')
# --> 313     return layer_module.deserialize(config, custom_objects=custom_objects)
#     314
#     315
#
# /home/dcek/anaconda2/envs/py27/lib/python2.7/site-packages/keras/layers/__init__.pyc in deserialize(config, custom_objects)
#      52                                     module_objects=globs,
#      53                                     custom_objects=custom_objects,
# ---> 54                                     printable_module_name='layer')
#
# /home/dcek/anaconda2/envs/py27/lib/python2.7/site-packages/keras/utils/generic_utils.pyc in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     137                 return cls.from_config(config['config'],
#     138                                        custom_objects=dict(list(_GLOBAL_CUSTOM_OBJECTS.items()) +
# --> 139                                                            list(custom_objects.items())))
#     140             with CustomObjectScope(custom_objects):
#     141                 return cls.from_config(config['config'])
#
# /home/dcek/anaconda2/envs/py27/lib/python2.7/site-packages/keras/engine/topology.pyc in from_config(cls, config, custom_objects)
#    2485         # First, we create all layers and enqueue nodes to be processed
#    2486         for layer_data in config['layers']:
# -> 2487             process_layer(layer_data)
#    2488         # Then we process nodes in order of layer depth.
#    2489         # Nodes that cannot yet be processed (if the inbound node
#
# /home/dcek/anaconda2/envs/py27/lib/python2.7/site-packages/keras/engine/topology.pyc in process_layer(layer_data)
#    2471
#    2472             layer = deserialize_layer(layer_data,
# -> 2473                                       custom_objects=custom_objects)
#    2474             created_layers[layer_name] = layer
#    2475
#
# /home/dcek/anaconda2/envs/py27/lib/python2.7/site-packages/keras/layers/__init__.pyc in deserialize(config, custom_objects)
#      52                                     module_objects=globs,
#      53                                     custom_objects=custom_objects,
# ---> 54                                     printable_module_name='layer')
#
# /home/dcek/anaconda2/envs/py27/lib/python2.7/site-packages/keras/utils/generic_utils.pyc in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     131             if cls is None:
#     132                 raise ValueError('Unknown ' + printable_module_name +
# --> 133                                  ': ' + class_name)
#     134         if hasattr(cls, 'from_config'):
#     135             custom_objects = custom_objects or {}
#
# ValueError: Unknown layer: Attention

# %%
MODEL_NAME = 'multi-labelNLP-second'
second_model = ToxModel()
second_model.train(0,train, text_column = 'comment_text', toxic = 'toxic', severe_toxic = 'severe_toxic', obscene = 'obscene', threat = 'threat', insult = 'insult', identity_hate = 'identity_hate', model_name = MODEL_NAME)
# Out:
# Hyperparameters
# ---------------
# max_num_words: 10000
# dropout_rate: 0.3
# verbose: True
# cnn_pooling_sizes: [5, 5, 40]
# es_min_delta: 0
# learning_rate: 7e-05
# es_patience: 1
# batch_size: 128
# embedding_dim: 300
# epochs: 50
# cnn_filter_sizes: [128, 128, 128]
# cnn_kernel_sizes: [5, 5, 5]
# max_sequence_length: 250
# stop_early: False
# embedding_trainable: False
#
# Fitting tokenizer...
# Tokenizer fitted!
# Preparing data...
# train_text_temp shape (159571, 250) and train_labels_temp shape (159571, 2)
#  ----
# valid_text shape (15958, 250) and valid_labels shape (15958, 2)
# train_text shape (143613, 250) and train_labels shape (143613, 2)
# Data prepared!
# Loading embeddings...
# Embeddings loaded!
# Building model graph...
# Training model...
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/50
# Epoch 00000: val_loss improved from inf to 0.19217, saving model to models/multi-labelNLP-second_model.h5
# 493s - loss: 0.3494 - acc: 0.9083 - val_loss: 0.1922 - val_acc: 0.9470
# Epoch 2/50
# Epoch 00001: val_loss improved from 0.19217 to 0.08755, saving model to models/multi-labelNLP-second_model.h5
# 490s - loss: 0.1361 - acc: 0.9628 - val_loss: 0.0875 - val_acc: 0.9753
# Epoch 3/50
# Epoch 00002: val_loss improved from 0.08755 to 0.07809, saving model to models/multi-labelNLP-second_model.h5
# 487s - loss: 0.0950 - acc: 0.9723 - val_loss: 0.0781 - val_acc: 0.9763
# Epoch 4/50
# Epoch 00003: val_loss improved from 0.07809 to 0.07406, saving model to models/multi-labelNLP-second_model.h5
# 489s - loss: 0.0862 - acc: 0.9736 - val_loss: 0.0741 - val_acc: 0.9765
# Epoch 5/50
# Epoch 00004: val_loss improved from 0.07406 to 0.07107, saving model to models/multi-labelNLP-second_model.h5
# 490s - loss: 0.0803 - acc: 0.9746 - val_loss: 0.0711 - val_acc: 0.9773
# Epoch 6/50
# Epoch 00005: val_loss improved from 0.07107 to 0.06934, saving model to models/multi-labelNLP-second_model.h5
# 490s - loss: 0.0766 - acc: 0.9754 - val_loss: 0.0693 - val_acc: 0.9773
# Epoch 7/50
# Epoch 00006: val_loss improved from 0.06934 to 0.06853, saving model to models/multi-labelNLP-second_model.h5
# 491s - loss: 0.0736 - acc: 0.9763 - val_loss: 0.0685 - val_acc: 0.9770
# Epoch 8/50
# Epoch 00007: val_loss improved from 0.06853 to 0.06745, saving model to models/multi-labelNLP-second_model.h5
# 491s - loss: 0.0703 - acc: 0.9769 - val_loss: 0.0675 - val_acc: 0.9779
# Epoch 9/50
# Epoch 00008: val_loss improved from 0.06745 to 0.06683, saving model to models/multi-labelNLP-second_model.h5
# 491s - loss: 0.0681 - acc: 0.9774 - val_loss: 0.0668 - val_acc: 0.9772
# Epoch 10/50
# Epoch 00009: val_loss did not improve
# 487s - loss: 0.0656 - acc: 0.9779 - val_loss: 0.0681 - val_acc: 0.9778
# Epoch 11/50
# Epoch 00010: val_loss improved from 0.06683 to 0.06667, saving model to models/multi-labelNLP-second_model.h5
# 491s - loss: 0.0634 - acc: 0.9786 - val_loss: 0.0667 - val_acc: 0.9778
# Epoch 12/50
# Epoch 00011: val_loss did not improve
# 487s - loss: 0.0614 - acc: 0.9794 - val_loss: 0.0692 - val_acc: 0.9777
# Epoch 13/50
# Epoch 00012: val_loss did not improve
# 487s - loss: 0.0592 - acc: 0.9798 - val_loss: 0.0668 - val_acc: 0.9778
# Epoch 14/50
# Epoch 00013: val_loss did not improve
# 487s - loss: 0.0566 - acc: 0.9807 - val_loss: 0.0678 - val_acc: 0.9775
# Epoch 15/50
# Epoch 00014: val_loss did not improve
# 488s - loss: 0.0543 - acc: 0.9816 - val_loss: 0.0685 - val_acc: 0.9781
# Epoch 16/50
# Epoch 00015: val_loss did not improve
# 487s - loss: 0.0524 - acc: 0.9820 - val_loss: 0.0701 - val_acc: 0.9779
# Epoch 17/50
# Epoch 00016: val_loss did not improve
# 487s - loss: 0.0501 - acc: 0.9829 - val_loss: 0.0729 - val_acc: 0.9776
# Epoch 18/50
# Epoch 00017: val_loss did not improve
# 487s - loss: 0.0486 - acc: 0.9833 - val_loss: 0.0747 - val_acc: 0.9774
# Epoch 19/50
# Epoch 00018: val_loss did not improve
# 487s - loss: 0.0469 - acc: 0.9839 - val_loss: 0.0708 - val_acc: 0.9769
# Epoch 20/50
# Epoch 00019: val_loss did not improve
# 487s - loss: 0.0450 - acc: 0.9847 - val_loss: 0.0744 - val_acc: 0.9775
# Epoch 21/50
# Epoch 00020: val_loss did not improve
# 487s - loss: 0.0436 - acc: 0.9849 - val_loss: 0.0726 - val_acc: 0.9764
# Epoch 22/50
# Epoch 00021: val_loss did not improve
# 487s - loss: 0.0421 - acc: 0.9857 - val_loss: 0.0769 - val_acc: 0.9765
# Epoch 23/50
# Epoch 00022: val_loss did not improve
# 488s - loss: 0.0414 - acc: 0.9860 - val_loss: 0.0779 - val_acc: 0.9773
# Epoch 24/50
# Epoch 00023: val_loss did not improve
# 488s - loss: 0.0395 - acc: 0.9866 - val_loss: 0.0769 - val_acc: 0.9764
# Epoch 25/50
# Epoch 00024: val_loss did not improve
# 489s - loss: 0.0379 - acc: 0.9870 - val_loss: 0.0835 - val_acc: 0.9775
# Epoch 26/50
# Epoch 00025: val_loss did not improve
# 488s - loss: 0.0377 - acc: 0.9871 - val_loss: 0.0825 - val_acc: 0.9773
# Epoch 27/50
# Epoch 00026: val_loss did not improve
# 486s - loss: 0.0368 - acc: 0.9876 - val_loss: 0.0819 - val_acc: 0.9766
# Epoch 28/50
# Epoch 00027: val_loss did not improve
# 487s - loss: 0.0356 - acc: 0.9878 - val_loss: 0.0811 - val_acc: 0.9765
# Epoch 29/50
# Epoch 00028: val_loss did not improve
# 488s - loss: 0.0345 - acc: 0.9883 - val_loss: 0.0872 - val_acc: 0.9768
# Epoch 30/50
# Epoch 00029: val_loss did not improve
# 488s - loss: 0.0341 - acc: 0.9884 - val_loss: 0.0817 - val_acc: 0.9769
# Epoch 31/50
# Epoch 00030: val_loss did not improve
# 488s - loss: 0.0331 - acc: 0.9889 - val_loss: 0.0859 - val_acc: 0.9771
# Epoch 32/50
# Epoch 00031: val_loss did not improve
# 488s - loss: 0.0323 - acc: 0.9890 - val_loss: 0.0879 - val_acc: 0.9772
# Epoch 33/50
# Epoch 00032: val_loss did not improve
# 488s - loss: 0.0315 - acc: 0.9893 - val_loss: 0.0857 - val_acc: 0.9773
# Epoch 34/50
# Epoch 00033: val_loss did not improve
# 488s - loss: 0.0310 - acc: 0.9893 - val_loss: 0.0854 - val_acc: 0.9768
# Epoch 35/50
# Epoch 00034: val_loss did not improve
# 490s - loss: 0.0302 - acc: 0.9897 - val_loss: 0.0870 - val_acc: 0.9767
# Epoch 36/50
# Epoch 00035: val_loss did not improve
# 491s - loss: 0.0296 - acc: 0.9901 - val_loss: 0.0870 - val_acc: 0.9770
# Epoch 37/50
# Epoch 00036: val_loss did not improve
# 489s - loss: 0.0296 - acc: 0.9898 - val_loss: 0.0862 - val_acc: 0.9765
# Epoch 38/50
# Epoch 00037: val_loss did not improve
# 489s - loss: 0.0289 - acc: 0.9900 - val_loss: 0.0862 - val_acc: 0.9766
# Epoch 39/50
# Epoch 00038: val_loss did not improve
# 491s - loss: 0.0282 - acc: 0.9902 - val_loss: 0.0878 - val_acc: 0.9771
# Epoch 40/50
# Epoch 00039: val_loss did not improve
# 495s - loss: 0.0280 - acc: 0.9905 - val_loss: 0.0853 - val_acc: 0.9765
# Epoch 41/50
# Epoch 00040: val_loss did not improve
# 493s - loss: 0.0273 - acc: 0.9905 - val_loss: 0.0899 - val_acc: 0.9770
# Epoch 42/50
# Epoch 00041: val_loss did not improve
# 494s - loss: 0.0271 - acc: 0.9908 - val_loss: 0.0954 - val_acc: 0.9767
# Epoch 43/50
# Epoch 00042: val_loss did not improve
# 496s - loss: 0.0268 - acc: 0.9907 - val_loss: 0.0919 - val_acc: 0.9763
# Epoch 44/50
# Epoch 00043: val_loss did not improve
# 503s - loss: 0.0262 - acc: 0.9908 - val_loss: 0.0933 - val_acc: 0.9764
# Epoch 45/50
# Epoch 00044: val_loss did not improve
# 497s - loss: 0.0263 - acc: 0.9908 - val_loss: 0.0919 - val_acc: 0.9761
# Epoch 46/50
# Epoch 00045: val_loss did not improve
# 496s - loss: 0.0254 - acc: 0.9912 - val_loss: 0.0918 - val_acc: 0.9770
# Epoch 47/50
# Epoch 00046: val_loss did not improve
# 498s - loss: 0.0246 - acc: 0.9913 - val_loss: 0.0938 - val_acc: 0.9766
# Epoch 48/50
# Epoch 00047: val_loss did not improve
# 502s - loss: 0.0246 - acc: 0.9912 - val_loss: 0.0922 - val_acc: 0.9763
# Epoch 49/50
# Epoch 00048: val_loss did not improve
# 498s - loss: 0.0243 - acc: 0.9914 - val_loss: 0.0981 - val_acc: 0.9765
# Epoch 50/50
# Epoch 00049: val_loss did not improve
# 487s - loss: 0.0242 - acc: 0.9915 - val_loss: 0.0957 - val_acc: 0.9764
# Model trained!
# Best model saved to models/multi-labelNLP-second_model.h5
# Loading best model from checkpoint...
# Model loaded!

# %%
debias_random_model = ToxModel(model_name="multi-labelNLP-gru-cv0")
# Out:
# Hyperparameters
# ---------------
# max_num_words: 30000
# dropout_rate: 0.3
# verbose: True
# cnn_pooling_sizes: [5, 5, 40]
# es_min_delta: 0
# learning_rate: 7e-05
# embedding_dim: 300
# cnn_kernel_sizes: [5, 5, 5]
# es_patience: 1
# epochs: 50
# cnn_filter_sizes: [128, 128, 128]
# batch_size: 128
# model_name: multi-labelNLP-gru-cv
# max_sequence_length: 250
# stop_early: False
# embedding_trainable: False

# %%
second_model = ToxModel(model_name="multi-labelNLP-second")
# Out:
# Hyperparameters
# ---------------
# max_num_words: 10000
# dropout_rate: 0.3
# verbose: True
# cnn_pooling_sizes: [5, 5, 40]
# es_min_delta: 0
# learning_rate: 7e-05
# embedding_dim: 300
# cnn_kernel_sizes: [5, 5, 5]
# es_patience: 1
# epochs: 50
# cnn_filter_sizes: [128, 128, 128]
# batch_size: 128
# model_name: multi-labelNLP-second
# max_sequence_length: 250
# stop_early: False
# embedding_trainable: False

# %%
import numpy as np
random_test = pd.read_csv('test.csv')
np.where(pd.isnull(random_test)) #check null rows
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
print(random_test.iloc[52300]) #print value of null row
# Out:
# id                                               56cf8b7315e85f14
# comment_text    SOmebody fucked up the homepage plz edit!! tha...
# Name: 52300, dtype: object

# %%
random_test = pd.read_csv('test.csv')
#random_test = random_test.dropna()
prediction = debias_random_model.predict(random_test['comment_text'])

# %%
prediction.shape
# Out:
# (153164, 6)

# %%
random_test = pd.read_csv('test.csv')
random_test = random_test.dropna()
print(random_test.iloc[52300])
# Out:
# id                                                   231302702569
# comment_text    Just a note about external links: I have remov...
# Name: 52301, dtype: object

# %%
random_test.shape
# Out:
# (226997, 2)

# %%
for id, p in enumerate(prediction):
    if(id <20):
        print(p)
# Out:
# [0.94351786 0.07261173 0.87614065 0.2488063 ]
# [2.8036063e-04 2.0171970e-05 3.3794012e-04 2.7047885e-05]
# [0.0013453  0.00012583 0.00167132 0.00017606]
# [1.0656077e-04 9.6954127e-06 1.1833789e-04 1.3261302e-05]
# [9.6572866e-04 7.3803014e-05 1.2766599e-03 1.0159020e-04]
# [1.4914108e-04 1.2232612e-05 1.7201710e-04 1.6546424e-05]
# [3.7022735e-04 3.1974312e-05 4.6733892e-04 4.4136799e-05]
# [0.03845833 0.00216745 0.05712204 0.00358418]
# [0.00292935 0.00019908 0.005152   0.00027639]
# [1.1728035e-04 1.0837189e-05 1.2751747e-04 1.4890081e-05]
# [0.06014245 0.00027489 0.07595153 0.00041313]
# [0.0037365  0.00061411 0.00671029 0.00094831]
# [1.1792146e-04 6.9626149e-06 1.3104505e-04 8.9941350e-06]
# [1.12934598e-04 1.16250676e-05 1.20583965e-04 1.62092383e-05]
# [9.21920000e-05 9.38676385e-06 1.02012295e-04 1.30086419e-05]
# [3.8325472e-04 3.0754032e-05 4.9539335e-04 4.2015748e-05]
# [0.00463269 0.00045546 0.00638342 0.000654  ]
# [0.00668138 0.00048621 0.01024681 0.00069852]
# [1.05928797e-04 1.01692503e-05 1.12349095e-04 1.40255634e-05]
# [0.00128499 0.00022907 0.00140288 0.00034797]

# %%
#second model
random_test = pd.read_csv('test.csv')
random_test = random_test.dropna()
prediction_second = second_model.predict(random_test['comment_text'])
prediction_second.shape
# Out:
# (153164, 2)

# %%
for id, p in enumerate(prediction_second):
    if(id <20):
        print(p)
# Out:
# [0.98729837 0.32326353]
# [8.3768519e-04 1.1632358e-06]
# [1.1443039e-03 2.0584848e-06]
# [4.5535603e-04 3.8094805e-07]
# [2.3912357e-02 7.7905795e-05]
# [5.241920e-04 4.858725e-07]
# [2.1548306e-03 5.0328690e-06]
# [0.73191476 0.0132686 ]
# [0.03209163 0.00011017]
# [4.660586e-04 4.495613e-07]
# [0.43936914 0.00131104]
# [0.30907333 0.00103553]
# [6.220829e-04 5.968530e-07]
# [5.3532032e-04 4.9457026e-07]
# [4.8731244e-04 3.8716783e-07]
# [1.6188634e-03 2.8966961e-06]
# [1.9687539e-02 3.7851005e-05]
# [1.3295321e-02 4.3206492e-05]
# [5.089241e-04 4.337683e-07]
# [1.7802878e-03 3.2394330e-06]

# %%
random_test = pd.read_csv('test.csv')
#random_test = random_test.dropna()
test_id = random_test['id'].astype(str)

# %%
test_id.shape
# Out:
# (153164,)

# %%
header = ["id"]
df = pd.DataFrame(test_id, columns=header)
#display(df.head(n=20))

df.id = df.id.astype("str")
print(df.dtypes)
display(df.head(n=20))
#print(np.where(pd.isnull(df)))
#print(df.shape)
#df.reset_index(drop=True, inplace=True)
# Out:
# id    object
# dtype: object
#                   id
# 0   00001cee341fdb12
# 1   0000247867823ef7
# 2   00013b17ad220c46
# 3   00017563c3f7919a
# 4   00017695ad8997eb
# 5   0001ea8717f6de06
# 6   00024115d4cbde0f
# 7   000247e83dcc1211
# 8   00025358d4737918
# 9   00026d1092fe71cc
# 10  0002eadc3b301559
# 11  0002f87b16116a7f
# 12  0003806b11932181
# 13  0003e1cccfd5a40a
# 14  00059ace3e3e9a53
# 15  000634272d0d44eb
# 16  000663aff0fffc80
# 17  000689dd34e20979
# 18  000834769115370c
# 19  000844b52dee5f3f

# %%
#IF NO SPLIT
headers = ["toxic","severe_toxic","obscene","threat","insult","identity_hate"]
test_df = pd.DataFrame(prediction, columns=headers, dtype=float)
display(test_df.head(n=20))
print(np.where(pd.isnull(test_df)))
print(test_df.shape)
test_df.reset_index(drop=True, inplace=True)
# Out:
#        toxic  severe_toxic   obscene        threat        insult  \
# 0   0.999144  4.910571e-01  0.997201  1.553519e-02  9.842854e-01
# 1   0.000013  6.671647e-07  0.000010  1.191349e-07  4.216913e-06
# 2   0.000209  6.238616e-06  0.000085  1.348426e-06  3.153176e-05
# 3   0.000025  9.297542e-07  0.000012  3.098087e-07  4.252371e-06
# 4   0.002148  1.040108e-05  0.000469  3.862768e-05  1.052680e-04
# 5   0.000042  1.268990e-06  0.000016  2.848018e-07  4.899765e-06
# 6   0.000051  1.395919e-06  0.000016  6.946671e-07  7.570949e-06
# 7   0.071056  1.163827e-04  0.001971  1.682328e-06  8.182763e-04
# 8   0.801900  3.431676e-05  0.024083  2.839076e-06  1.149196e-01
# 9   0.000011  3.321367e-07  0.000007  5.973085e-08  1.487395e-06
# 10  0.753341  1.943194e-03  0.343263  5.293602e-05  1.177455e-02
# 11  0.000102  3.048829e-07  0.000027  2.795570e-08  8.914047e-06
# 12  0.000034  2.825011e-07  0.000022  4.486401e-08  2.500264e-06
# 13  0.000042  2.759356e-07  0.000011  2.391401e-08  3.936682e-06
# 14  0.000015  1.927926e-07  0.000004  3.109963e-08  6.017103e-07
# 15  0.000093  1.302868e-06  0.000015  1.435930e-07  8.811699e-06
# 16  0.000341  5.421381e-06  0.000211  3.351438e-07  4.865562e-05
# 17  0.000042  6.250647e-07  0.000013  3.199706e-08  3.575684e-06
# 18  0.000231  1.904634e-06  0.000070  4.873854e-07  1.486732e-05
# 19  0.002066  1.536943e-05  0.000404  8.524466e-06  1.095073e-04
#
#     identity_hate
# 0    1.343174e-01
# 1    5.983958e-07
# 2    5.135477e-06
# 3    1.555411e-07
# 4    2.039362e-05
# 5    3.813471e-07
# 6    4.054838e-07
# 7    6.897181e-06
# 8    1.346543e-05
# 9    1.684030e-07
# 10   2.340290e-05
# 11   2.755909e-06
# 12   5.238395e-07
# 13   1.305350e-07
# 14   1.128519e-07
# 15   8.281456e-07
# 16   2.953769e-06
# 17   2.659654e-07
# 18   2.688753e-07
# 19   4.031982e-06
# (array([], dtype=int64), array([], dtype=int64))
# (153164, 6)

# %%
#IF SPLIT
headers = ["toxic","severe_toxic"]
test_df_second = pd.DataFrame(prediction_second, columns=headers, dtype=float)
display(test_df_second.head(n=20))
print(np.where(pd.isnull(test_df_second)))
print(test_df_second.shape)
test_df_second.reset_index(drop=True, inplace=True)
# Out:
#        toxic  severe_toxic
# 0   0.987298  3.232635e-01
# 1   0.000838  1.163236e-06
# 2   0.001144  2.058485e-06
# 3   0.000455  3.809481e-07
# 4   0.023912  7.790580e-05
# 5   0.000524  4.858725e-07
# 6   0.002155  5.032869e-06
# 7   0.731915  1.326860e-02
# 8   0.032092  1.101697e-04
# 9   0.000466  4.495613e-07
# 10  0.439369  1.311041e-03
# 11  0.309073  1.035529e-03
# 12  0.000622  5.968530e-07
# 13  0.000535  4.945703e-07
# 14  0.000487  3.871678e-07
# 15  0.001619  2.896696e-06
# 16  0.019688  3.785100e-05
# 17  0.013295  4.320649e-05
# 18  0.000509  4.337683e-07
# 19  0.001780  3.239433e-06
# (array([], dtype=int64), array([], dtype=int64))
# (153164, 2)

# %%
headers = ["obscene","threat","insult","identity_hate"]
test_df = pd.DataFrame(prediction, columns=headers, dtype=float)
display(test_df.head(n=20))
print(np.where(pd.isnull(test_df)))
print(test_df.shape)
test_df.reset_index(drop=True, inplace=True)
# Out:
#      obscene    threat    insult  identity_hate
# 0   0.943518  0.072612  0.876141       0.248806
# 1   0.000280  0.000020  0.000338       0.000027
# 2   0.001345  0.000126  0.001671       0.000176
# 3   0.000107  0.000010  0.000118       0.000013
# 4   0.000966  0.000074  0.001277       0.000102
# 5   0.000149  0.000012  0.000172       0.000017
# 6   0.000370  0.000032  0.000467       0.000044
# 7   0.038458  0.002167  0.057122       0.003584
# 8   0.002929  0.000199  0.005152       0.000276
# 9   0.000117  0.000011  0.000128       0.000015
# 10  0.060142  0.000275  0.075952       0.000413
# 11  0.003737  0.000614  0.006710       0.000948
# 12  0.000118  0.000007  0.000131       0.000009
# 13  0.000113  0.000012  0.000121       0.000016
# 14  0.000092  0.000009  0.000102       0.000013
# 15  0.000383  0.000031  0.000495       0.000042
# 16  0.004633  0.000455  0.006383       0.000654
# 17  0.006681  0.000486  0.010247       0.000699
# 18  0.000106  0.000010  0.000112       0.000014
# 19  0.001285  0.000229  0.001403       0.000348
# (array([], dtype=int64), array([], dtype=int64))
# (153164, 4)

# %%
#IF NO SPLIT
df_new = pd.concat([df,test_df], axis=1)
#df_new = df.merge(test_df, how='outer')
#df_new.id = df_new.id.astype("int")
display(df_new.head(n=20))
print(df_new.dtypes)

np.where(pd.isnull(df_new))
# Out:
#                   id     toxic  severe_toxic   obscene        threat  \
# 0   00001cee341fdb12  0.999144  4.910571e-01  0.997201  1.553519e-02
# 1   0000247867823ef7  0.000013  6.671647e-07  0.000010  1.191349e-07
# 2   00013b17ad220c46  0.000209  6.238616e-06  0.000085  1.348426e-06
# 3   00017563c3f7919a  0.000025  9.297542e-07  0.000012  3.098087e-07
# 4   00017695ad8997eb  0.002148  1.040108e-05  0.000469  3.862768e-05
# 5   0001ea8717f6de06  0.000042  1.268990e-06  0.000016  2.848018e-07
# 6   00024115d4cbde0f  0.000051  1.395919e-06  0.000016  6.946671e-07
# 7   000247e83dcc1211  0.071056  1.163827e-04  0.001971  1.682328e-06
# 8   00025358d4737918  0.801900  3.431676e-05  0.024083  2.839076e-06
# 9   00026d1092fe71cc  0.000011  3.321367e-07  0.000007  5.973085e-08
# 10  0002eadc3b301559  0.753341  1.943194e-03  0.343263  5.293602e-05
# 11  0002f87b16116a7f  0.000102  3.048829e-07  0.000027  2.795570e-08
# 12  0003806b11932181  0.000034  2.825011e-07  0.000022  4.486401e-08
# 13  0003e1cccfd5a40a  0.000042  2.759356e-07  0.000011  2.391401e-08
# 14  00059ace3e3e9a53  0.000015  1.927926e-07  0.000004  3.109963e-08
# 15  000634272d0d44eb  0.000093  1.302868e-06  0.000015  1.435930e-07
# 16  000663aff0fffc80  0.000341  5.421381e-06  0.000211  3.351438e-07
# 17  000689dd34e20979  0.000042  6.250647e-07  0.000013  3.199706e-08
# 18  000834769115370c  0.000231  1.904634e-06  0.000070  4.873854e-07
# 19  000844b52dee5f3f  0.002066  1.536943e-05  0.000404  8.524466e-06
#
#           insult  identity_hate
# 0   9.842854e-01   1.343174e-01
# 1   4.216913e-06   5.983958e-07
# 2   3.153176e-05   5.135477e-06
# 3   4.252371e-06   1.555411e-07
# 4   1.052680e-04   2.039362e-05
# 5   4.899765e-06   3.813471e-07
# 6   7.570949e-06   4.054838e-07
# 7   8.182763e-04   6.897181e-06
# 8   1.149196e-01   1.346543e-05
# 9   1.487395e-06   1.684030e-07
# 10  1.177455e-02   2.340290e-05
# 11  8.914047e-06   2.755909e-06
# 12  2.500264e-06   5.238395e-07
# 13  3.936682e-06   1.305350e-07
# 14  6.017103e-07   1.128519e-07
# 15  8.811699e-06   8.281456e-07
# 16  4.865562e-05   2.953769e-06
# 17  3.575684e-06   2.659654e-07
# 18  1.486732e-05   2.688753e-07
# 19  1.095073e-04   4.031982e-06
# id                object
# toxic            float64
# severe_toxic     float64
# obscene          float64
# threat           float64
# insult           float64
# identity_hate    float64
# dtype: object
# (array([], dtype=int64), array([], dtype=int64))

# %%
#IF SPLIT
df_new = pd.concat([df,test_df_second,test_df], axis=1)
#df_new = df.merge(test_df, how='outer')
#df_new.id = df_new.id.astype("int")
display(df_new.head(n=20))
print(df_new.dtypes)

np.where(pd.isnull(df_new))
# Out:
#                   id     toxic  severe_toxic   obscene    threat    insult  \
# 0   00001cee341fdb12  0.987298  3.232635e-01  0.943518  0.072612  0.876141
# 1   0000247867823ef7  0.000838  1.163236e-06  0.000280  0.000020  0.000338
# 2   00013b17ad220c46  0.001144  2.058485e-06  0.001345  0.000126  0.001671
# 3   00017563c3f7919a  0.000455  3.809481e-07  0.000107  0.000010  0.000118
# 4   00017695ad8997eb  0.023912  7.790580e-05  0.000966  0.000074  0.001277
# 5   0001ea8717f6de06  0.000524  4.858725e-07  0.000149  0.000012  0.000172
# 6   00024115d4cbde0f  0.002155  5.032869e-06  0.000370  0.000032  0.000467
# 7   000247e83dcc1211  0.731915  1.326860e-02  0.038458  0.002167  0.057122
# 8   00025358d4737918  0.032092  1.101697e-04  0.002929  0.000199  0.005152
# 9   00026d1092fe71cc  0.000466  4.495613e-07  0.000117  0.000011  0.000128
# 10  0002eadc3b301559  0.439369  1.311041e-03  0.060142  0.000275  0.075952
# 11  0002f87b16116a7f  0.309073  1.035529e-03  0.003737  0.000614  0.006710
# 12  0003806b11932181  0.000622  5.968530e-07  0.000118  0.000007  0.000131
# 13  0003e1cccfd5a40a  0.000535  4.945703e-07  0.000113  0.000012  0.000121
# 14  00059ace3e3e9a53  0.000487  3.871678e-07  0.000092  0.000009  0.000102
# 15  000634272d0d44eb  0.001619  2.896696e-06  0.000383  0.000031  0.000495
# 16  000663aff0fffc80  0.019688  3.785100e-05  0.004633  0.000455  0.006383
# 17  000689dd34e20979  0.013295  4.320649e-05  0.006681  0.000486  0.010247
# 18  000834769115370c  0.000509  4.337683e-07  0.000106  0.000010  0.000112
# 19  000844b52dee5f3f  0.001780  3.239433e-06  0.001285  0.000229  0.001403
#
#     identity_hate
# 0        0.248806
# 1        0.000027
# 2        0.000176
# 3        0.000013
# 4        0.000102
# 5        0.000017
# 6        0.000044
# 7        0.003584
# 8        0.000276
# 9        0.000015
# 10       0.000413
# 11       0.000948
# 12       0.000009
# 13       0.000016
# 14       0.000013
# 15       0.000042
# 16       0.000654
# 17       0.000699
# 18       0.000014
# 19       0.000348
# id                object
# toxic            float64
# severe_toxic     float64
# obscene          float64
# threat           float64
# insult           float64
# identity_hate    float64
# dtype: object
# (array([], dtype=int64), array([], dtype=int64))

# %%
#hds = ["id","toxic","severe_toxic","obscene","threat","insult","identity_hate"]

#df2 = pd.DataFrame([[231298963278,0.5,0.5,0.5,0.5,0.5,0.5]], columns = hds)
#df_newer = df_new.append(df2)

# %%
df_new.shape
# Out:
# (153164, 7)

# %%
head = ["id","toxic","severe_toxic","obscene","threat","insult","identity_hate"]
df_new.to_csv('cv_gru_output.csv', columns = head, index=False)

# %%
for id, p in enumerate(prediction):

# %% [markdown]
# ### Plain wikipedia model

# %%
MODEL_NAME = 'cnn_wiki_tox_v3'
wiki_model = ToxModel()
wiki_model.train(wiki['train'], wiki['dev'], text_column = 'comment', label_column = 'is_toxic', model_name = MODEL_NAME)
# Out:
# Hyperparameters
# ---------------
# max_num_words: 10000
# dropout_rate: 0.3
# verbose: True
# cnn_pooling_sizes: [5, 5, 40]
# es_min_delta: 0
# learning_rate: 5e-05
# es_patience: 1
# batch_size: 128
# embedding_dim: 100
# epochs: 20
# cnn_filter_sizes: [128, 128, 128]
# cnn_kernel_sizes: [5, 5, 5]
# max_sequence_length: 250
# stop_early: True
# embedding_trainable: False
#
# Fitting tokenizer...
# Tokenizer fitted!
# Preparing data...
# Data prepared!
# Loading embeddings...
# Embeddings loaded!
# Building model graph...
# Training model...
# Train on 95692 samples, validate on 32128 samples
# Epoch 1/20
# Epoch 00000: val_loss improved from inf to 0.17471, saving model to ../models/cnn_wiki_tox_v3_model.h5
# 134s - loss: 0.2437 - acc: 0.9141 - val_loss: 0.1747 - val_acc: 0.9359
# Epoch 2/20
# Epoch 00001: val_loss improved from 0.17471 to 0.14997, saving model to ../models/cnn_wiki_tox_v3_model.h5
# 134s - loss: 0.1654 - acc: 0.9388 - val_loss: 0.1500 - val_acc: 0.9439
# Epoch 3/20
# Epoch 00002: val_loss improved from 0.14997 to 0.13735, saving model to ../models/cnn_wiki_tox_v3_model.h5
# 134s - loss: 0.1467 - acc: 0.9455 - val_loss: 0.1373 - val_acc: 0.9492
# Epoch 4/20
# Epoch 00003: val_loss improved from 0.13735 to 0.13248, saving model to ../models/cnn_wiki_tox_v3_model.h5
# 135s - loss: 0.1345 - acc: 0.9497 - val_loss: 0.1325 - val_acc: 0.9516
# Epoch 5/20
# Epoch 00004: val_loss improved from 0.13248 to 0.12877, saving model to ../models/cnn_wiki_tox_v3_model.h5
# 135s - loss: 0.1258 - acc: 0.9535 - val_loss: 0.1288 - val_acc: 0.9536
# Epoch 6/20
# Epoch 00005: val_loss did not improve
# 135s - loss: 0.1188 - acc: 0.9560 - val_loss: 0.1297 - val_acc: 0.9498
# Epoch 7/20
# Epoch 00006: val_loss improved from 0.12877 to 0.12534, saving model to ../models/cnn_wiki_tox_v3_model.h5
# 140s - loss: 0.1131 - acc: 0.9584 - val_loss: 0.1253 - val_acc: 0.9550
# Epoch 8/20
# Epoch 00007: val_loss did not improve
# 135s - loss: 0.1078 - acc: 0.9598 - val_loss: 0.1269 - val_acc: 0.9521
# Epoch 9/20
# Epoch 00008: val_loss did not improve
# 135s - loss: 0.1015 - acc: 0.9622 - val_loss: 0.1288 - val_acc: 0.9554
# Epoch 00008: early stopping
# Model trained!
# Best model saved to ../models/cnn_wiki_tox_v3_model.h5
# Loading best model from checkpoint...
# Model loaded!

# %%
wiki_test = pd.read_csv(wiki['test'])
wiki_model.score_auc(wiki_test['comment'], wiki_test['is_toxic'])
# Out:
# 0.95997760130597887

# %% [markdown]
# ### Debiased model

# %%
MODEL_NAME = 'cnn_debias_tox_v3'
debias_model = ToxModel()
debias_model.train(debias['train'], debias['dev'], text_column = 'comment', label_column = 'is_toxic', model_name = MODEL_NAME)
# Out:
# Hyperparameters
# ---------------
# max_num_words: 10000
# dropout_rate: 0.3
# verbose: True
# cnn_pooling_sizes: [5, 5, 40]
# es_min_delta: 0
# learning_rate: 5e-05
# es_patience: 1
# batch_size: 128
# embedding_dim: 100
# epochs: 20
# cnn_filter_sizes: [128, 128, 128]
# cnn_kernel_sizes: [5, 5, 5]
# max_sequence_length: 250
# stop_early: True
# embedding_trainable: False
#
# Fitting tokenizer...
# Tokenizer fitted!
# Preparing data...
# Data prepared!
# Loading embeddings...
# Embeddings loaded!
# Building model graph...
# Training model...
# Train on 99157 samples, validate on 33283 samples
# Epoch 1/20
# Epoch 00000: val_loss improved from inf to 0.16575, saving model to ../models/cnn_debias_tox_v3_model.h5
# 140s - loss: 0.2258 - acc: 0.9215 - val_loss: 0.1657 - val_acc: 0.9406
# Epoch 2/20
# Epoch 00001: val_loss improved from 0.16575 to 0.14430, saving model to ../models/cnn_debias_tox_v3_model.h5
# 139s - loss: 0.1595 - acc: 0.9420 - val_loss: 0.1443 - val_acc: 0.9472
# Epoch 3/20
# Epoch 00002: val_loss improved from 0.14430 to 0.13724, saving model to ../models/cnn_debias_tox_v3_model.h5
# 140s - loss: 0.1414 - acc: 0.9482 - val_loss: 0.1372 - val_acc: 0.9502
# Epoch 4/20
# Epoch 00003: val_loss improved from 0.13724 to 0.13068, saving model to ../models/cnn_debias_tox_v3_model.h5
# 140s - loss: 0.1307 - acc: 0.9521 - val_loss: 0.1307 - val_acc: 0.9525
# Epoch 5/20
# Epoch 00004: val_loss did not improve
# 140s - loss: 0.1229 - acc: 0.9543 - val_loss: 0.1316 - val_acc: 0.9540
# Epoch 6/20
# Epoch 00005: val_loss improved from 0.13068 to 0.12352, saving model to ../models/cnn_debias_tox_v3_model.h5
# 140s - loss: 0.1168 - acc: 0.9566 - val_loss: 0.1235 - val_acc: 0.9541
# Epoch 7/20
# Epoch 00006: val_loss did not improve
# 140s - loss: 0.1105 - acc: 0.9596 - val_loss: 0.1244 - val_acc: 0.9563
# Epoch 8/20
# Epoch 00007: val_loss improved from 0.12352 to 0.12325, saving model to ../models/cnn_debias_tox_v3_model.h5
# 149s - loss: 0.1054 - acc: 0.9612 - val_loss: 0.1232 - val_acc: 0.9548
# Epoch 9/20
# Epoch 00008: val_loss improved from 0.12325 to 0.12280, saving model to ../models/cnn_debias_tox_v3_model.h5
# 147s - loss: 0.1004 - acc: 0.9631 - val_loss: 0.1228 - val_acc: 0.9559
# Epoch 10/20
# Epoch 00009: val_loss did not improve
# 140s - loss: 0.0947 - acc: 0.9652 - val_loss: 0.1256 - val_acc: 0.9546
# Epoch 11/20
# Epoch 00010: val_loss did not improve
# 139s - loss: 0.0896 - acc: 0.9674 - val_loss: 0.1249 - val_acc: 0.9550
# Epoch 00010: early stopping
# Model trained!
# Best model saved to ../models/cnn_debias_tox_v3_model.h5
# Loading best model from checkpoint...
# Model loaded!

# %%
debias_test = pd.read_csv(debias['test'])
debias_model.prep_data_and_score(debias_test['comment'], debias_test['is_toxic'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-c2e330991cd3> in <module>()
#       1 debias_test = pd.read_csv(debias['test'])
# ----> 2 debias_model.prep_data_and_score(debias_test['comment'], debias_test['is_toxic'])
#
# AttributeError: ToxModel instance has no attribute 'prep_data_and_score'
